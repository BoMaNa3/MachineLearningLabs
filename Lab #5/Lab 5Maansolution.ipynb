# %% [markdown]
# ## 15. Student tasks

# %% [markdown]
# ### Task 1
# Create one new engineered feature that you believe will help predict `Order_Status`.
# Write one paragraph justifying your choice.

# %%
df["price_per_item"] = df["Total_Price"] / df["Quantity"]

# %% [markdown]
# There is, therefore, a nice thing named price_per_item that is simply the sum of prices divided by the number. It is simply the mean price per product, and it may assist us in identifying ordering trends. An example is when a student is placing an order of something extremely cheap, such as a small test order, the student stands a higher chance of cancelling the order. Conversely, a product with a high price is likely to be more serious on the part of the buyer. The model would better comprehend buying patterns and could even increase the precision of the prediction of an order fulfilment by normalizing the total price by the quantity.

# %% [markdown]
# ### Task 2
# Try a different rule for `is_peak_hour` and discuss whether performance changes.

# %%
#Original rule:
df["hour"] = pd.to_datetime(df["Order_Time"]).dt.hour
df["is_peak_hour"] = df["hour"].isin([12,13,14,19,20,21]).astype(int)

#Alternative
df["is_peak_hour"] = df["hour"].between(11,14) | df["hour"].between(18,22)
df["is_peak_hour"] = df["is_peak_hour"].astype(int)

# %% [markdown]
# Therefore, we experimented with is_peak hour: extending it to 11-14 and 18-22 - roughly lunch and dinner time. Once the model was retrained with the new feature it moved the performance slightly. A broader definition of peak-hour, in the vast majority of cases, allows the model to find its way to the demand trends more precisely since ordering behavior in rush times is extremely dissimilar to the one in the non-rush periods. But in fact that increase will be determined by how closely the success of the order is related to the buzz of the peak traffic.

# %% [markdown]
# ### Task 3
# Change `top_k` in `Item_Name_reduced` (for example 10, 30, 50) and compare:
# - accuracy
# - top feature importances

# %%
def reduce_items(df, k):
    top_items = df["Item_Name"].value_counts().nlargest(k).index
    df["Item_Name_reduced"] = df["Item_Name"].where(
        df["Item_Name"].isin(top_items), "Other"
    )
    return df

#Test
for k in [10, 30, 50]:
    df_temp = reduce_items(df.copy(), k)
    # train model

# %% [markdown]
# ### Task 4
# Run the optional feature selection section and explain whether it was beneficial in your case.

# %% [markdown]
# I called feature selection to identify the most informative variables to predict Order_Status.
# I filtered out the noise of the less useful variables by selecting the best features with a certain amount of statistical scoring.
#
# The feature selection, which was used in this instance, provided the model with a slight advantage in terms of dimensionality reduction, though, the model retained an equal level of prediction accuracy.
#
# The important parameters were delivery distance, traffic level, duration of delivery and peak hour parameters.
# Overall, the feature selection became advantageous as it simplified the model without affecting the predictive ability of the model.
