# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Chocolate Sales.csv")

# Display its shape
print(df.shape)

# Preview the first few rows
df.head()

# Check column names and data types
df.dtypes
